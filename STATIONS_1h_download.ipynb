# %% [markdown]
# # Introduction
#
# Example script for downloading hourly station data.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Modules

# %%
import datetime as dt
from pathlib import Path

import ipywidgets as widgets
import numpy as np
import pandas as pd
from IPython.display import display

from ZAMGdatahub import data_download, metadata, query, utils

# %% [markdown]
# ## Global variables

# %%
# set output directory
ODIR = "/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/"
ODIR = Path(ODIR)
# ODIR = "."
# ODIR = Path(ODIR).resolve()
# ODIR = ODIR.joinpath("test_downloads")

if not ODIR.is_dir():
    ODIR.mkdir(parents=True)

# variable
params = ["RSX", "GSW", "RSX", "SCH", "TT"]


# var_convert = pd.read_csv("data/ST", index_col=0)["var_id"].to_dict()
parameter_meta = pd.read_csv(
    Path("data").joinpath("STD_Parameter-Metadaten.csv"), index_col=0
)
stations_meta = pd.read_csv(Path("data").joinpath("STD_Stations-Metadaten.csv"))

datetimeformat = "%Y-%m-%d %H:%M"
start = dt.datetime(1880, 4, 1).strftime(datetimeformat)
end = dt.datetime.now().strftime(datetimeformat)

overwrite = False
verbose = True
parallelProcess = True

# %%
param_ids = [i for i in parameter_meta.index if len(i) < 4]
parameter_meta.loc[param_ids]
# Out:
#                          Kurzbeschreibung  \
# D2X              Windrichtung in Sektoren
# D6X                          Windrichtung
# FFX                      Relative Feuchte
# GSR             Globalstrahlung ungeeicht
# GSW                       Globalstrahlung
# GSX                       Globalstrahlung
# HSR             Diffusstrahlung ungeeicht
# HSX                       Diffusstrahlung
# LT2                Lufttemperatur in 5 cm
# PPX              Luftdruck Stationsniveau
# PPY  Luftdruck auf Meeresniveau reduziert
# RS2                        Niederschlag 2
# RSD                    Niederschlagsdauer
# RSX                          Niederschlag
# SCH                            Schneehöhe
# SST      Direkte Sonnenstrahlung (direkt)
# SUX                     Sonnenscheindauer
# TDX                   Taupunktstemperatur
# TT0    Erdbodentemperatur in 200 cm Tiefe
# TT2     Erdbodentemperatur in 10 cm Tiefe
# TT3     Erdbodentemperatur in 20 cm Tiefe
# TT4     Erdbodentemperatur in 50 cm Tiefe
# TT5    Erdbodentemperatur in 100 cm Tiefe
# TTX                Lufttemperatur 2 meter
# VKM                   Windgeschwindigkeit
# VPX                            Dampfdruck
# VVX                   Windgeschwindigkeit
# WSD           Windrichtung der Windspitze
# WSK                           Windspitzen
# WSX                           Windspitzen
# WSZ                   Zeit der Windspitze
#
#                                           Beschreibung           Einheit
# D2X                Windrichtung in Sektoren: 32-teilig               NaN
# D6X  Windrichtung in ° - vektorielles Mittel aus 10...                 °
# FFX  Relative Luftfeuchte - letzter 10 Minutenwert ...                 %
# GSR                          Globalstrahlung ungeeicht                mV
# GSW  Globalstrahlung - Mittelwert aus 10 Minuten-We...              W/m²
# GSX  Globalstrahlung - Mittelwert aus 10 Minuten-We...             J/cm²
# HSR  Diffusstrahlung ungeeicht - Mittelwert aus 10 ...                mV
# HSX  Diffusstrahlung - Mittelwert aus 10 Minuten-We...  J/cm² pro Stunde
# LT2  Lufttemperatur in 5 cm über dem Boden - minima...                °C
# PPX  Luftdruck Stationsniveau - letzter 10 Minutenw...              mbar
# PPY               Luftdruck auf Meeresniveau reduziert              mbar
# RS2                                     Niederschlag 2                mm
# RSD  Niederschlagsdauer - 60 Minuten-Summe ((hh-1):...               min
# RSX  Niederschlag - 60 Minuten-Summe ((hh-1):00:01 ...                mm
# SCH  Schneehöhe - aus Schneepegel,  letzter 10 Minu...                cm
# SST                   Direkte Sonnenstrahlung (direkt)  J/cm² pro Stunde
# SUX  Sonnenscheindauer - Summe((hh-1):10 -hh:00) in...                 h
# TDX  Taupunktstemperatur -  letzter 10 Minutenwert ...                °C
# TT0  Erdbodentemperatur in 200 cm Tiefe -  letzter ...                °C
# TT2  Erdbodentemperatur in 10 cm Tiefe -  letzter 1...                °C
# TT3  Erdbodentemperatur in 20 cm Tiefe -  letzter 1...                °C
# TT4  Erdbodentemperatur in 50 cm Tiefe -  letzter 1...                °C
# TT5  Erdbodentemperatur in 100 cm Tiefe -  letzter ...                °C
# TTX  Lufttemperatur 2 meter -  letzter 10 Minutenwe...                °C
# VKM                                Windgeschwindigkeit              km/h
# VPX                                         Dampfdruck              mbar
# VVX  Windgeschwindigkeit - verktorielles Mittel aus...               m/s
# WSD  Windrichtung der Windspitze -  ddx zum Zeitpun...                 °
# WSK                                        Windspitzen              km/h
# WSX  Windspitzen -  Maximum von ffx (in der Stunde ...               m/s
# WSZ  Zeit der Windspitze -  zum maximalen ffx gehör...               NaN

# %% [markdown]
# # Functions

# %%
def getParameterWithFlags(params, parameter_meta):
    params_extra = []
    for key in params:
        params_extra = params_extra + [
            par for par in parameter_meta.index if par[: len(key)] == key
        ]

    return params_extra


def stationsInGridbox(stations_meta, gridbox: query.LatLonBox):
    # find stations in right longitude range
    lon_mask = np.logical_and(
        stations_meta["Länge [°E]"].values < gridbox.lon_max,
        stations_meta["Länge [°E]"].values > gridbox.lon_min,
    )
    # find stations in right latitude range
    lat_mask = np.logical_and(
        stations_meta["Breite [°N]"].values < gridbox.lat_max,
        stations_meta["Breite [°N]"].values > gridbox.lat_min,
    )
    # combine the masks
    mask = np.logical_and(lat_mask, lon_mask)
    return stations_meta[mask]

# %% [markdown]
# # Make query

# %% [markdown]
# ## Dataset

# %%
# dataset type
dataset = query.DatasetType.STATION_1h
print(dataset)
# Out:
# DatasetType.STATION_1h

# %% [markdown]
# ## Select parameters

# %%
params_extra = getParameterWithFlags(params, parameter_meta)
parameter_meta.loc[params_extra]
# Out:
#                              Kurzbeschreibung  \
# RSX                              Niederschlag
# RSX_qflag              Qualitätsqflag für RSX
# RSX_typ                  Qualitätstyp für RSX
# GSW                           Globalstrahlung
# GSW_qflag              Qualitätsqflag für GSW
# GSW_typ                  Qualitätstyp für GSW
# RSX                              Niederschlag
# RSX_qflag              Qualitätsqflag für RSX
# RSX_typ                  Qualitätstyp für RSX
# SCH                                Schneehöhe
# SCH_qflag              Qualitätsqflag für SCH
# SCH_typ                  Qualitätstyp für SCH
# TT0        Erdbodentemperatur in 200 cm Tiefe
# TT0_qflag              Qualitätsqflag für TT0
# TT0_typ                  Qualitätstyp für TT0
# TT2         Erdbodentemperatur in 10 cm Tiefe
# TT2_qflag              Qualitätsqflag für TT2
# TT2_typ                  Qualitätstyp für TT2
# TT3         Erdbodentemperatur in 20 cm Tiefe
# TT3_qflag              Qualitätsqflag für TT3
# TT3_typ                  Qualitätstyp für TT3
# TT4         Erdbodentemperatur in 50 cm Tiefe
# TT4_qflag              Qualitätsqflag für TT4
# TT4_typ                  Qualitätstyp für TT4
# TT5        Erdbodentemperatur in 100 cm Tiefe
# TT5_qflag              Qualitätsqflag für TT5
# TT5_typ                  Qualitätstyp für TT5
# TTX                    Lufttemperatur 2 meter
# TTX_qflag              Qualitätsqflag für TTX
# TTX_typ                  Qualitätstyp für TTX
#
#                                                 Beschreibung Einheit
# RSX        Niederschlag - 60 Minuten-Summe ((hh-1):00:01 ...      mm
# RSX_qflag  Qualitätsqflag für RSX - Qualitätsflag={0-2: u...     NaN
# RSX_typ    Qualitätstyp für RSX - Qualitätsflag={0-2: nic...     NaN
# GSW        Globalstrahlung - Mittelwert aus 10 Minuten-We...    W/m²
# GSW_qflag  Qualitätsqflag für GSW - Qualitätsflag={0-2: u...     NaN
# GSW_typ    Qualitätstyp für GSW - Qualitätsflag={0-2: nic...     NaN
# RSX        Niederschlag - 60 Minuten-Summe ((hh-1):00:01 ...      mm
# RSX_qflag  Qualitätsqflag für RSX - Qualitätsflag={0-2: u...     NaN
# RSX_typ    Qualitätstyp für RSX - Qualitätsflag={0-2: nic...     NaN
# SCH        Schneehöhe - aus Schneepegel,  letzter 10 Minu...      cm
# SCH_qflag  Qualitätsqflag für SCH - Qualitätsflag={0-2: u...     NaN
# SCH_typ    Qualitätstyp für SCH - Qualitätsflag={0-2: nic...     NaN
# TT0        Erdbodentemperatur in 200 cm Tiefe -  letzter ...      °C
# TT0_qflag  Qualitätsqflag für TT0 - Qualitätsflag={0-2: u...     NaN
# TT0_typ    Qualitätstyp für TT0 - Qualitätsflag={0-2: nic...     NaN
# TT2        Erdbodentemperatur in 10 cm Tiefe -  letzter 1...      °C
# TT2_qflag  Qualitätsqflag für TT2 - Qualitätsflag={0-2: u...     NaN
# TT2_typ    Qualitätstyp für TT2 - Qualitätsflag={0-2: nic...     NaN
# TT3        Erdbodentemperatur in 20 cm Tiefe -  letzter 1...      °C
# TT3_qflag  Qualitätsqflag für TT3 - Qualitätsflag={0-2: u...     NaN
# TT3_typ    Qualitätstyp für TT3 - Qualitätsflag={0-2: nic...     NaN
# TT4        Erdbodentemperatur in 50 cm Tiefe -  letzter 1...      °C
# TT4_qflag  Qualitätsqflag für TT4 - Qualitätsflag={0-2: u...     NaN
# TT4_typ    Qualitätstyp für TT4 - Qualitätsflag={0-2: nic...     NaN
# TT5        Erdbodentemperatur in 100 cm Tiefe -  letzter ...      °C
# TT5_qflag  Qualitätsqflag für TT5 - Qualitätsflag={0-2: u...     NaN
# TT5_typ    Qualitätstyp für TT5 - Qualitätsflag={0-2: nic...     NaN
# TTX        Lufttemperatur 2 meter -  letzter 10 Minutenwe...      °C
# TTX_qflag  Qualitätsqflag für TTX - Qualitätsflag={0-2: u...     NaN
# TTX_typ    Qualitätstyp für TTX - Qualitätsflag={0-2: nic...     NaN

# %% [markdown]
# ## Selecting stations

# %%
gridbox_oetz = query.LatLonBox(
    label="oetztal", lat_min=46.6, lat_max=47.3, lon_min=10.5, lon_max=11.4
)
print(gridbox_oetz)
print()

# gridbox for all Tirol
gridbox_tirol = query.LatLonBox(
    label="tirol", lat_min=46.77, lat_max=47.71, lon_min=9.53, lon_max=13.51
)
print(gridbox_tirol)
print()
# Out:
# LOCATION: oetztal
# COORDINATES: latitude: 46.6 ... 47.3 ; longitude 10.5 ... 11.4
#
# LOCATION: tirol
# COORDINATES: latitude: 46.77 ... 47.71 ; longitude 9.53 ... 13.51

# %%
# find stations within gridbox
stations_oetz = stationsInGridbox(stations_meta, gridbox_oetz)
station_ids = stations_oetz.id.values
station_names = stations_oetz.Stationsname.to_list()
station_starts = stations_oetz.Startdatum.to_list()
stations_oetz
# Out:
#         id  Synopstationsnummer         Stationsname  Länge [°E]  Breite [°N]  \
# 190  11800              11120.0  INNSBRUCK-FLUGPLATZ   11.355278    47.258888
# 191  11801                  NaN      INNSBRUCK-UNIV.   11.385000    47.260555
# 192  11803              11320.0      INNSBRUCK-UNIV.   11.384167    47.259998
# 193  11804              11120.0  INNSBRUCK-FLUGPLATZ   11.356667    47.259998
# 218  14400              11112.0              LANDECK   10.566667    47.133335
# 219  14500                  NaN          HOCHSERFAUS   10.600000    47.033333
# 220  14525                  NaN               FAGGEN   10.683333    47.083332
# 221  14631              11117.0             UMHAUSEN   10.928889    47.139168
# 264  17300              11127.0            OBERGURGL   11.027223    46.867500
# 265  17301              11127.0            OBERGURGL   11.024445    46.866943
# 266  17305                  NaN                 VENT   10.933333    46.866665
# 267  17315              11316.0  PITZTALER GLETSCHER   10.879167    46.926945
# 268  17320              11318.0         BRUNNENKOGEL   10.861667    46.912777
# 475  14701              11324.0     NEUSTIFT/MILDERS   11.291945    47.102779
# 476  14630                  NaN             UMHAUSEN   10.933888    47.137501
# 477  14622              11317.0  ST.LEONHARD/PITZTAL   10.865556    47.027222
# 478  14620                  NaN             PIOESMES   10.866667    47.049999
# 479  14603              11309.0              HAIMING   10.889444    47.259724
# 481  14520                  NaN                PRUTZ   10.666667    47.066666
# 482  14513              11115.0                 IMST   10.742222    47.236946
# 483  14510              11115.0                 IMST   10.741667    47.236111
# 484  14403              11112.0              LANDECK   10.563611    47.140278
# 485  14401              11112.0              LANDECK   10.566667    47.133335
#
#      Höhe [m]  Startdatum    Enddatum Bundesland Sonnenschein Globalstrahlung
# 190     579.0  1971-01-01  1989-12-31        TIR         nein              ja
# 191     577.0  1921-12-01  2008-04-30        TIR           ja              ja
# 192     578.0  1986-05-01  2100-12-31        TIR           ja              ja
# 193     578.0  1992-07-01  2100-12-31        TIR           ja              ja
# 218     818.0  1978-01-01  1981-12-31        TIR         nein            nein
# 219    1815.0  1961-01-01  1976-12-31        TIR           ja              ja
# 220     900.0  1961-01-01  1969-03-31        TIR           ja            nein
# 221    1035.0  2003-07-01  2100-12-31        TIR         nein              ja
# 264    1938.0  1953-05-01  1998-12-31        TIR           ja            nein
# 265    1941.0  1999-01-01  2100-12-31        TIR           ja              ja
# 266    1908.0  1939-01-01  1977-12-31        TIR           ja            nein
# 267    2863.9  1993-12-16  2100-12-31        TIR           ja              ja
# 268    3437.0  2003-07-01  2100-12-31        TIR         nein            nein
# 475    1007.0  2004-11-01  2100-12-31        TIR         nein              ja
# 476    1041.0  1961-01-01  2003-05-31        TIR         nein            nein
# 477    1454.4  2007-11-27  2100-12-31        TIR         nein              ja
# 478    1410.0  1980-01-01  1982-12-31        TIR           ja            nein
# 479     659.0  2007-08-01  2100-12-31        TIR           ja              ja
# 481     870.0  1967-07-01  2008-01-31        TIR           ja            nein
# 482     773.0  2007-08-01  2100-12-31        TIR           ja              ja
# 483     785.0  1980-01-01  1983-05-31        TIR           ja            nein
# 484     796.0  1993-07-01  2100-12-31        TIR           ja              ja
# 485     785.0  1986-01-01  1993-09-30        TIR           ja              ja

# %% [markdown]
# ## Make the query

# %%
myQuery = query.StationQuery(
    dataset, params_extra, station_ids, station_names, station_starts
)

print(myQuery)
# Out:
# stationQuery for download of STATION_1h.
# params: ['RSX', 'RSX_qflag', 'RSX_typ', 'GSW', 'GSW_qflag', 'GSW_typ', 'RSX', 'RSX_qflag', 'RSX_typ', 'SCH', 'SCH_qflag', 'SCH_typ', 'TT0', 'TT0_qflag', 'TT0_typ', 'TT2', 'TT2_qflag', 'TT2_typ', 'TT3', 'TT3_qflag', 'TT3_typ', 'TT4', 'TT4_qflag', 'TT4_typ', 'TT5', 'TT5_qflag', 'TT5_typ', 'TTX', 'TTX_qflag', 'TTX_typ']
# dataset: DatasetType.STATION_1h
# station_ids: ['11800', '11801', '11803', '11804', '14400', '14500', '14525', '14631', '17300', '17301', '17305', '17315', '17320', '14701', '14630', '14622', '14620', '14603', '14520', '14513', '14510', '14403', '14401']
# station_names: ['INNSBRUCK-FLUGPLATZ', 'INNSBRUCK-UNIV.', 'INNSBRUCK-UNIV.', 'INNSBRUCK-FLUGPLATZ', 'LANDECK', 'HOCHSERFAUS', 'FAGGEN', 'UMHAUSEN', 'OBERGURGL', 'OBERGURGL', 'VENT', 'PITZTALER GLETSCHER', 'BRUNNENKOGEL', 'NEUSTIFT/MILDERS', 'UMHAUSEN', 'ST.LEONHARD/PITZTAL', 'PIOESMES', 'HAIMING', 'PRUTZ', 'IMST', 'IMST', 'LANDECK', 'LANDECK']
# station_longnames: ['11800_INNSBRUCK-FLUGPLATZ', '11801_INNSBRUCK-UNIV.', '11803_INNSBRUCK-UNIV.', '11804_INNSBRUCK-FLUGPLATZ', '14400_LANDECK', '14500_HOCHSERFAUS', '14525_FAGGEN', '14631_UMHAUSEN', '17300_OBERGURGL', '17301_OBERGURGL', '17305_VENT', '17315_PITZTALER-GLETSCHER', '17320_BRUNNENKOGEL', '14701_NEUSTIFT-MILDERS', '14630_UMHAUSEN', '14622_ST.LEONHARD-PITZTAL', '14620_PIOESMES', '14603_HAIMING', '14520_PRUTZ', '14513_IMST', '14510_IMST', '14403_LANDECK', '14401_LANDECK']
# station_starts: ['1971-01-01', '1921-12-01', '1986-05-01', '1992-07-01', '1978-01-01', '1961-01-01', '1961-01-01', '2003-07-01', '1953-05-01', '1999-01-01', '1939-01-01', '1993-12-16', '2003-07-01', '2004-11-01', '1961-01-01', '2007-11-27', '1980-01-01', '2007-08-01', '1967-07-01', '2007-08-01', '1980-01-01', '1993-07-01', '1986-01-01']
# output_format: csv
# annualSlices: True
# location_label: station-selection
# output_filename_head: station-hourly

# %% [markdown]
# ## Save/Load query to/from file

# %%
myQuery.saveQuery()
# Out:
# Query saved to "./STATION_1h_query_station-selection.txt"

# %%
importedQuery = query.loadQuery("./STATION_1h_query_station-selection.txt")
print(importedQuery)
# Out:
# stationQuery for download of STATION_1h.
# params: ['RSX', 'RSX_qflag', 'RSX_typ', 'GSW', 'GSW_qflag', 'GSW_typ', 'RSX', 'RSX_qflag', 'RSX_typ', 'SCH', 'SCH_qflag', 'SCH_typ', 'TT0', 'TT0_qflag', 'TT0_typ', 'TT2', 'TT2_qflag', 'TT2_typ', 'TT3', 'TT3_qflag', 'TT3_typ', 'TT4', 'TT4_qflag', 'TT4_typ', 'TT5', 'TT5_qflag', 'TT5_typ', 'TTX', 'TTX_qflag', 'TTX_typ']
# dataset: DatasetType.STATION_1h
# station_ids: ['11800', '11801', '11803', '11804', '14400', '14500', '14525', '14631', '17300', '17301', '17305', '17315', '17320', '14701', '14630', '14622', '14620', '14603', '14520', '14513', '14510', '14403', '14401']
# station_names: ['INNSBRUCK-FLUGPLATZ', 'INNSBRUCK-UNIV.', 'INNSBRUCK-UNIV.', 'INNSBRUCK-FLUGPLATZ', 'LANDECK', 'HOCHSERFAUS', 'FAGGEN', 'UMHAUSEN', 'OBERGURGL', 'OBERGURGL', 'VENT', 'PITZTALER GLETSCHER', 'BRUNNENKOGEL', 'NEUSTIFT/MILDERS', 'UMHAUSEN', 'ST.LEONHARD/PITZTAL', 'PIOESMES', 'HAIMING', 'PRUTZ', 'IMST', 'IMST', 'LANDECK', 'LANDECK']
# station_longnames: ['11800_INNSBRUCK-FLUGPLATZ', '11801_INNSBRUCK-UNIV.', '11803_INNSBRUCK-UNIV.', '11804_INNSBRUCK-FLUGPLATZ', '14400_LANDECK', '14500_HOCHSERFAUS', '14525_FAGGEN', '14631_UMHAUSEN', '17300_OBERGURGL', '17301_OBERGURGL', '17305_VENT', '17315_PITZTALER-GLETSCHER', '17320_BRUNNENKOGEL', '14701_NEUSTIFT-MILDERS', '14630_UMHAUSEN', '14622_ST.LEONHARD-PITZTAL', '14620_PIOESMES', '14603_HAIMING', '14520_PRUTZ', '14513_IMST', '14510_IMST', '14403_LANDECK', '14401_LANDECK']
# station_starts: ['1971-01-01', '1921-12-01', '1986-05-01', '1992-07-01', '1978-01-01', '1961-01-01', '1961-01-01', '2003-07-01', '1953-05-01', '1999-01-01', '1939-01-01', '1993-12-16', '2003-07-01', '2004-11-01', '1961-01-01', '2007-11-27', '1980-01-01', '2007-08-01', '1967-07-01', '2007-08-01', '1980-01-01', '1993-07-01', '1986-01-01']
# output_format: csv
# annualSlices: True
# location_label: station-selection
# output_filename_head: station-hourly

# %% [markdown]
# # Download

# %%
# save the metadata on selected parameters
parameter_meta.loc[params_extra].to_csv(
    ODIR.joinpath("ZAMG_station-hourly_parameter_metadata.csv")
)
# save the station selection
stations_oetz.to_csv(ODIR.joinpath("ZAMG_station-hourly_stations_metadata.csv"))

# %%
if not len(utils.makeStationFilenames(start, end, myQuery)) == len(
    data_download.makeURL(myQuery, start, end)
):
    raise Exception(
        "Something went wrong when splitting station data requests into slices. No garantee that filenames and file contents match!"
    )

# %%
data_download.downloadData(
    myQuery,
    start,
    end,
    ODIR,
    overwrite=overwrite,
    verbose=verbose,
    parallelProcess=parallelProcess,
)
# Out:
# Parallelising with 5 cores.
# 11800_INNSBRUCK-FLUGPLATZ_station-hourly_2020.csv11801_INNSBRUCK-UNIV._station-hourly_1967.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_1971.csv11804_INNSBRUCK-FLUGPLATZ_station-hourly_1997.csv11801_INNSBRUCK-UNIV._station-hourly_2016.csv     has already been downloaded:has already been downloaded:has already been downloaded:has already been downloaded:has already been downloaded:     /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1971.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_2020.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1967.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_1997.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2016.csv
#
#
#
#
# 11800_INNSBRUCK-FLUGPLATZ_station-hourly_1972.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_2021.csv11801_INNSBRUCK-UNIV._station-hourly_1968.csv11801_INNSBRUCK-UNIV._station-hourly_2017.csv  11804_INNSBRUCK-FLUGPLATZ_station-hourly_1998.csv  has already been downloaded:has already been downloaded:has already been downloaded:  has already been downloaded:  has already been downloaded:/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1972.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1968.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_2021.csv
#
#
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2017.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_1998.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_1973.csv
# 11800_INNSBRUCK-FLUGPLATZ_station-hourly_2022.csv11801_INNSBRUCK-UNIV._station-hourly_1969.csv
#  11801_INNSBRUCK-UNIV._station-hourly_2018.csv  has already been downloaded:11804_INNSBRUCK-FLUGPLATZ_station-hourly_1999.csv has already been downloaded:has already been downloaded:  has already been downloaded:  /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1973.csvhas already been downloaded: /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_2022.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1969.csv
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2018.csv
#
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_1999.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_1974.csv
# 11801_INNSBRUCK-UNIV._station-hourly_1921.csv11801_INNSBRUCK-UNIV._station-hourly_1970.csv
#  11801_INNSBRUCK-UNIV._station-hourly_2019.csv 11804_INNSBRUCK-FLUGPLATZ_station-hourly_2000.csvhas already been downloaded:  has already been downloaded: has already been downloaded:has already been downloaded:  has already been downloaded:  /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1921.csv /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1974.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1970.csv
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_2000.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2019.csv
#
# 11801_INNSBRUCK-UNIV._station-hourly_1922.csv
#
# 11800_INNSBRUCK-FLUGPLATZ_station-hourly_1975.csv11801_INNSBRUCK-UNIV._station-hourly_1971.csv 11804_INNSBRUCK-FLUGPLATZ_station-hourly_2001.csv  11801_INNSBRUCK-UNIV._station-hourly_2020.csvhas already been downloaded:has already been downloaded:has already been downloaded:     /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1922.csvhas already been downloaded:has already been downloaded:/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1971.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1975.csv
#
#
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2020.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_2001.csv11801_INNSBRUCK-UNIV._station-hourly_1972.csv11801_INNSBRUCK-UNIV._station-hourly_1923.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_1976.csv
#
#    11801_INNSBRUCK-UNIV._station-hourly_2021.csv11804_INNSBRUCK-FLUGPLATZ_station-hourly_2002.csvhas already been downloaded:has already been downloaded: has already been downloaded:    has already been downloaded:has already been downloaded:/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1972.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1923.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1976.csv
#
#
# /home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_2021.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11804_INNSBRUCK-FLUGPLATZ/11804_INNSBRUCK-FLUGPLATZ_station-hourly_2002.csv11801_INNSBRUCK-UNIV._station-hourly_1973.csv11801_INNSBRUCK-UNIV._station-hourly_1924.csv11800_INNSBRUCK-FLUGPLATZ_station-hourly_1977.csv
#
#    11804_INNSBRUCK-FLUGPLATZ_station-hourly_2003.csv11801_INNSBRUCK-UNIV._station-hourly_2022.csvhas already been downloaded:has already been downloaded:has already been downloaded:     has already been downloaded:has already been downloaded:/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11800_INNSBRUCK-FLUGPLATZ/11800_INNSBRUCK-FLUGPLATZ_station-hourly_1977.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1924.csv/home/skalevag/Documents/NRC_P8_water_energy_and_sediment/data/meteo_stations/11801_INNSBRUCK-UNIV./11801_INNSBRUCK-UNIV._station-hourly_1973.csv
